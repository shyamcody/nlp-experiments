# %% [markdown]
# <a href="https://colab.research.google.com/github/shyamcody/nlp-experiments/blob/master/automated_title_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget URL https://gist.githubusercontent.com/hamletbatista/5f6718a653acf8092144c37007f0d063/raw/84d17c0460b8914f4b76a8699ba0743b3af279d5/hootsuite_titles.csv
# Out:
# --2020-12-12 17:00:49--  http://url/
# Resolving url (url)... failed: Name or service not known.
# wget: unable to resolve host address ‘url’
# --2020-12-12 17:00:49--  https://gist.githubusercontent.com/hamletbatista/5f6718a653acf8092144c37007f0d063/raw/84d17c0460b8914f4b76a8699ba0743b3af279d5/hootsuite_titles.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 150662 (147K) [text/plain]
# Saving to: ‘hootsuite_titles.csv.1’
#
# hootsuite_titles.cs 100%[===================>] 147.13K  --.-KB/s    in 0.02s
#
# 2020-12-12 17:00:49 (9.32 MB/s) - ‘hootsuite_titles.csv.1’ saved [150662/150662]
#
# FINISHED --2020-12-12 17:00:49--
# Total wall clock time: 0.4s
# Downloaded: 1 files, 147K in 0.02s (9.32 MB/s)

# %%
# !pip install ludwig

# %%
# !pip install ludwig[text]

# %%
import pandas as pd
df = pd.read_csv("hootsuite_titles.csv")

df.head()
# Out:
#    Unnamed: 0  ... Optimized
# 0          15  ...        90
# 1          18  ...        91
# 2          21  ...        90
# 3          29  ...        89
# 4          48  ...        84
#
# [5 rows x 5 columns]

# %%
# !wget https://gist.githubusercontent.com/hamletbatista/1f9a86d4364f641f776808bff03f557b/raw/b282ece4a48ebb2c0a50f8d16c1a5a089ee7530b/t5_config.yaml
# Out:
# --2020-12-12 17:04:58--  https://gist.githubusercontent.com/hamletbatista/1f9a86d4364f641f776808bff03f557b/raw/b282ece4a48ebb2c0a50f8d16c1a5a089ee7530b/t5_config.yaml
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 493 [text/plain]
# Saving to: ‘t5_config.yaml.1’
#
# t5_config.yaml.1    100%[===================>]     493  --.-KB/s    in 0s
#
# 2020-12-12 17:04:58 (34.6 MB/s) - ‘t5_config.yaml.1’ saved [493/493]

# %%
from google.colab import files 
files.upload()
# Out:
#      <input type="file" id="files-844a4e22-ad49-4571-ada4-a4710d011581" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-844a4e22-ad49-4571-ada4-a4710d011581">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving t5_config_modif.yaml to t5_config_modif.yaml
# {'t5_config_modif.yaml': b'input_features :\n    -\n        name: Original_Title\n        type: text\n        level: word\n        encoder: t5\n        reduce_output: null\n    -\n        name: Keyword\n        type: text\n        level: word\n        tied_weights: Original_Title\n        encoder: t5\n        reduce_output: null\n\noutput_features :\n    -\n        name: Optimized_Title\n        type: sequence\n        level: word\n        decoder: generator\n'}

# %%
# !ludwig train --dataset hootsuite_titles.csv --config t5_config_modif.yaml
# Out:
# 2020-12-12 17:08:33.201938: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.3.1 - Train
#
# 2020-12-12 17:08:34.339054: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-12 17:08:34.404190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-12 17:08:34.404769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !wget URL https://gist.githubusercontent.com/hamletbatista/1c4cfc0f24f6ac9774dd18a1f6e5b020/raw/7756f21ba5fbf02c2fe9043ffda06e525a06ea34/hootsuite_titles_to_optimize.csv
# Out:
# --2020-12-12 17:51:07--  http://url/
# Resolving url (url)... failed: Name or service not known.
# wget: unable to resolve host address ‘url’
# --2020-12-12 17:51:07--  https://gist.githubusercontent.com/hamletbatista/1c4cfc0f24f6ac9774dd18a1f6e5b020/raw/7756f21ba5fbf02c2fe9043ffda06e525a06ea34/hootsuite_titles_to_optimize.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7940 (7.8K) [text/plain]
# Saving to: ‘hootsuite_titles_to_optimize.csv’
#
# hootsuite_titles_to 100%[===================>]   7.75K  --.-KB/s    in 0s
#
# 2020-12-12 17:51:07 (94.5 MB/s) - ‘hootsuite_titles_to_optimize.csv’ saved [7940/7940]
#
# FINISHED --2020-12-12 17:51:07--
# Total wall clock time: 0.3s
# Downloaded: 1 files, 7.8K in 0s (94.5 MB/s)

# %%
# !ludwig predict --dataset hootsuite_titles_to_optimize.csv --model_path results/experiment_run/model/
# Out:
# 2020-12-12 17:51:15.681846: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.3.1 - Predict
#
# Dataset path: hootsuite_titles_to_optimize.csv
# Model path: results/experiment_run/model/
#
# 2020-12-12 17:51:16.879646: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-12 17:51:16.914675: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-12 17:51:16.915310: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# ...

# %%
import torch

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !mv results/experiment_run/model/* /content/gdrive/MyDrive/Colab\ Notebooks/model/

# %% [markdown]
# The end~~
